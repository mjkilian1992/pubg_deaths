# %%
from pubg.pipelines import kill_distances as pubg_pipeline_kill_distances

# %%
pubg_pipeline_kill_distances.build_kill_distance_dataset(
    '../data/deaths/kill_match_stats_final_0.csv',
    '../data/enriched/deaths/kills_with_distances_0.csv'
)
# Out:
# /home/mkilian/workspace/pubg_deaths/pubg/deaths/api/transforms.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deaths_df[pubg_deaths_definitions.KILL_DISTANCE] = kill_distance_series

# %%
import pandas
pandas.read_csv('../data/enriched/deaths/kills_with_distances_0.csv', encoding='utf-8', nrows=100)
# Out:
#     Unnamed: 0     killed_by       killer_name  killer_placement      map  \
# 0            0       Grenade   KrazyPortuguese               5.0  MIRAMAR
# 1            1        SCAR-L  nide2Bxiaojiejie              31.0  MIRAMAR
# 2            2          S686          Ascholes              43.0  MIRAMAR
# 3            3  Down and Out        Weirdo7777               9.0  MIRAMAR
# 4            4          M416         Solayuki1               9.0  MIRAMAR
# ..         ...           ...               ...               ...      ...
# 95          98         S1897       yueliandiyi               1.0  MIRAMAR
# 96          99           SKS        QuY-BeO---              22.0  MIRAMAR
# 97         100  Down and Out      SuperViolent              12.0  MIRAMAR
# 98         101  Down and Out         651651646               1.0  MIRAMAR
# 99         102         M16A4      SuperViolent              12.0  MIRAMAR
#
#                                              match_id  time      victim_name  \
# ...
