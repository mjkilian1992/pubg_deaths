# %%
import pandas
import matplotlib

# %matplotlib notebook

from numpy.linalg import norm

# %%
from pubg.deaths import (
    definitions as pubg_deaths_definitions, input as pubg_deaths_input)

# %%
FILENAME = '../data/deaths/kill_match_stats_final_0.csv'
df = pubg_deaths_input.read_deaths_file_to_dataframe(FILENAME)

# %%
df[df['killer_name'].isnull()]
# Out:
#              killed_by killer_name  killer_placement      map  \
# 44            Bluezone         NaN               NaN  MIRAMAR
# 76            Bluezone         NaN               NaN  MIRAMAR
# 78        Down and Out         NaN               NaN  MIRAMAR
# 97        Down and Out         NaN              24.0  MIRAMAR
# 111              Win94         NaN              11.0  MIRAMAR
# ...                ...         ...               ...      ...
# 13426252      Bluezone         NaN               NaN  MIRAMAR
# 13426253      Bluezone         NaN               NaN  MIRAMAR
# 13426313  Down and Out         NaN               NaN  ERANGEL
# 13426340         Buggy         NaN               NaN  ERANGEL
# 13426343      Bluezone         NaN               NaN  ERANGEL
#
#                                                    match_id  time  \
# 44        2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   879
# 76        2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...  1646
# 78        2U4GBNA0YmnLSqvEycnTjo-KT000vfUnhSA2vfVhVPe1QB...   879
# 97        2U4GBNA0Yml3HEnAb5HSfMbBgZnnKeFS1Nyxgm5XowlAkE...   178
# 111       2U4GBNA0Yml3HEnAb5HSfMbBgZnnKeFS1Nyxgm5XowlAkE...   415
# ...                                                     ...   ...
# 13426252  2U4GBNA0YmlWc_jEcSfkfTtWimxqUoNXDijilJ0EXsIlud...  1392
# 13426253  2U4GBNA0YmlWc_jEcSfkfTtWimxqUoNXDijilJ0EXsIlud...  1393
# 13426313  2U4GBNA0YmkTZQvSzreuDJjVgxqK1nIRqCKc5yGZ5INIVZ...   882
# 13426340  2U4GBNA0YmkTZQvSzreuDJjVgxqK1nIRqCKc5yGZ5INIVZ...   761
# 13426343  2U4GBNA0YmkTZQvSzreuDJjVgxqK1nIRqCKc5yGZ5INIVZ...  1519
#
#             victim_name  victim_placement  killer_x_metres  killer_y_metres  \
# 44        xuezhiqian717              26.0              NaN              NaN
# 76            zd1994925               7.0              NaN              NaN
# 78        WOJIAOLIGUAPI              26.0              NaN              NaN
# 97           SylarBreak              23.0             4378             2807
# 111                 NaN              11.0             3150             3570
# ...                 ...               ...              ...              ...
# 13426252      jya895441              11.0              NaN              NaN
# 13426253    zm467645621              11.0              NaN              NaN
# 13426313       AcEMaiNo              28.0              NaN              NaN
# 13426340     Yang_Zong_               5.0              NaN              NaN
# 13426343     Carmen_Amy              28.0              NaN              NaN
#
#           victim_x_metres  victim_y_metres
# 44                      0                0
# 76                      0                0
# 78                      0                0
# 97                   4385             2808
# 111                  3150             3570
# ...                   ...              ...
# 13426252             4355             3158
# 13426253             4354             3159
# 13426313                0                0
# 13426340             4060             4025
# 13426343             1652             6012
#
# [990101 rows x 12 columns]
